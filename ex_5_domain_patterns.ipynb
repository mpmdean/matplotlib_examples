# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.ticker as ticker
from cycler import cycle

from gradient_fill import gradient_fill

# %matplotlib notebook

# %% [markdown]
# ## Create random patterns as a test

# %%
patterns = [np.random.rand(20, 20) for n in range(6)]

# %% [markdown]
# Ths using matplotlibrc file from
# https://github.com/mpmdean/matplotlibrc
# All fields are using latex by default -- this avoid non-uniformity when using latex in some labels.

# %%
import sys
print("Python version is {} \n".format(sys.version))
print("Matplotlib version is {} \n".format(mpl.__version__))
print("Matplotlibrc file is {}\n".format(mpl.matplotlib_fname()))
# Out:
# Python version is 3.6.1 |Continuum Analytics, Inc.| (default, Mar 22 2017, 19:25:17)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# Matplotlib version is 2.0.0
#
# Matplotlibrc file is /Users/markdean/.matplotlib/matplotlibrc

# %% [markdown]
# ## Create figure

# %%
fig, axs = plt.subplots(2, 3, figsize=(6, 4))

color = 'k'
for ax, pattern, label in zip(axs.ravel(), patterns, 'abcdef'):
    ax.imshow(pattern)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.text(0.11, 0.9, '({})'.format(label), fontweight='black', color='k',
            verticalalignment='center', horizontalalignment='center',
            transform=ax.transAxes,
           bbox={'facecolor':'w', 'alpha':0.9}) #, 'pad':10

axs[0,0].set_ylabel('CDW domains')
axs[1,0].set_ylabel('Speckle pattern')


axs[0,0].set_title('$\sigma=4 \pm 2$ pixels')
axs[0,1].set_title('$\sigma=8 \pm 4$ pixels')
axs[0,2].set_title('$\sigma=10 \pm 2$ pixels')


fig.suptitle('Domain size', x=0.8)
totalax = fig.add_axes([0, 0, 1, 1])
totalax.axis('off')

totalax.arrow(0.2, 0.97, 0.45, 0,
              head_width=0.03, head_length=0.05, fc='k', ec='k')
fig.subplots_adjust(wspace=0.1, hspace=.1)#, left=0.05, right=0.97, bottom=0.15, top=0.95)

fig.savefig('ex_5_domain_patterns.pdf', dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="600">
