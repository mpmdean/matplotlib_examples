# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.rcParams['figure.dpi'] = 1200
plt.rcParams['savefig.dpi'] = 1200


# %matplotlib inline

# %%
def set_minors(ax):
    ax.xaxis.set_minor_locator(ticker.AutoMinorLocator(2))
    ax.yaxis.set_minor_locator(ticker.AutoMinorLocator(2))

# %%
scale = 2700
points = 3000
sigma = 300
Icalc = (np.random.rand(points)**3)*scale
Err_pm = np.random.normal(size=points, scale=sigma)
Imeasured = Icalc + Err_pm
Err = sigma

# %%
fig, ax = plt.subplots(figsize=(3+3/8, 2.5))

ax.plot([0, 3000], [0, 3000], 'r-')
ax.errorbar(Icalc, Imeasured, yerr=Err,
            errorevery=100,
            color='k', linestyle=None, fmt='.', markersize=1, alpha=.5)

ax.set_xlabel('Calculated intensity (arb. units)')
ax.set_ylabel('Measured intensity (arb. units)')
ax.axis([0, None, 0, None])
set_minors(ax)

plt.subplots_adjust(bottom=.2, left=.2)
fig.savefig('ex_24_many_points.pdf', dpi=1200)
